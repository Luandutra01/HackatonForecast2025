# %%
# !pip install pandas pyarrow torch tqdm joblib

# %%
import pandas as pd

# ================================
# Carregar dados
# ================================
df = pd.read_parquet("1.snappy.parquet")

# Filtrar para 2022
df['transaction_date'] = pd.to_datetime(df['transaction_date'], errors='coerce')
df_2022 = df[df['transaction_date'].dt.year == 2022].copy()
df_2022['semana'] = df_2022['transaction_date'].dt.to_period('W').apply(lambda r: r.start_time)

# ================================
# Remover outliers IQR=1.5
# ================================
def remove_outliers(df, col="quantity", k=1.5):
    def _iqr_filter(x):
        q1 = x.quantile(0.25)
        q3 = x.quantile(0.75)
        iqr = q3 - q1
        lower = q1 - k * iqr
        upper = q3 + k * iqr
        return x[(x >= lower) & (x <= upper)]
    return df.groupby(["internal_product_id", "internal_store_id"], group_keys=False).apply(
        lambda g: g.assign(**{col: _iqr_filter(g[col])})
    )

df_clean = remove_outliers(df_2022, col="quantity", k=1.5)

# ================================
# Média móvel dos 2 últimos valores
# ================================
df_clean = df_clean.sort_values(["internal_product_id", "internal_store_id", "semana"])
df_clean["quantity_smooth"] = df_clean.groupby(["internal_product_id", "internal_store_id"])['quantity'] \
    .transform(lambda x: x.rolling(2, min_periods=1).mean())

# ================================
# Contagem antes e depois da remoção de duplicados
# ================================
# Antes
semanas_por_prod_pdv_before = df_clean.groupby(['internal_product_id', 'internal_store_id'])['semana'].nunique()
count_before = (semanas_por_prod_pdv_before >= 6).sum()

# Remover duplicados
df_clean = df_clean.drop_duplicates(subset=["internal_product_id", "internal_store_id", "semana"])

# Depois
semanas_por_prod_pdv_after = df_clean.groupby(['internal_product_id', 'internal_store_id'])['semana'].nunique()
count_after = (semanas_por_prod_pdv_after >= 12).sum()

print(f"🔹 Produtos/PDVs com >= 12 semanas (antes): {count_before}")
print(f"🔹 Produtos/PDVs com >= 12 semanas (depois): {count_after}")

# ================================
# Média de semanas presentes por produto/pdv
# ================================
media_semanas_prod_pdv = semanas_por_prod_pdv_after.mean()
print(f"📊 Média de semanas presentes por produto/pdv após limpeza: {media_semanas_prod_pdv:.2f}")

# ================================
# Salvar dados tratados
# ================================
df_clean.to_parquet("dados_tratados.parquet", index=False)
print("✅ Arquivo 'dados_tratados.parquet' gerado para download.")
# Out:
# KeyboardInterrupt

# %%
import pandas as pd

# Carregar dados tratados
df = pd.read_parquet("dados_tratados.parquet")

# Remover linhas com NaN na coluna 'quantity'
df_filtrado = df.dropna(subset=['quantity', 'quantity_smooth'])

# Salvar novo arquivo sem NaN
df_filtrado.to_parquet("dados_tratados_sem_nan.parquet", index=False)
print("Arquivo 'dados_tratados_sem_nan.parquet' gerado sem valores NaN em 'quantity'.")

# %%
# ================================
# !pip install pandas pyarrow torch tqdm joblib
# ================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
import glob
import os
import time
import joblib
import warnings

warnings.filterwarnings("ignore")

# ================================
# Configurações principais
# ================================
BATCH_SIZE = 50000
OUTPUT_PREFIX = "previsoes_2023_mlp_batch"
N_SEMANAS_PREV = 5
WINDOW_DEFAULT = 10  # tamanho da janela padrão da MLP
MIN_SEMANAS_MLP = 10  # mínimo de semanas para usar MLP

# ================================
# Configuração GPU
# ================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("🚀 Usando dispositivo:", device)

# ================================
# Função para carregar dados
# ================================
def carregar_dados():
    df = pd.read_parquet("dados_tratados_sem_nan.parquet")
    df = df.rename(columns={
        "internal_store_id": "pdv",
        "internal_product_id": "produto",
        "quantity": "quantidade"
    })
    df = df.sort_values(["produto", "pdv", "semana"])
    df["produto"] = df["produto"].astype(str).str.strip()
    df["pdv"] = df["pdv"].astype(str).str.strip()
    return df[["semana", "pdv", "produto", "quantidade", "quantity_smooth"]]

# ================================
# Rede Neural Global (MLP simples)
# ================================
class MLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        return self.fc3(x)

# ================================
# Função de previsão MLP
# ================================
def prever_mlp(model, serie, window=WINDOW_DEFAULT, n_semanas=N_SEMANAS_PREV):
    ultimos = serie[-window:] if len(serie) >= window else [0]*(window - len(serie)) + serie
    preds = []
    model.eval()
    with torch.no_grad():
        for _ in range(n_semanas):
            inp = torch.tensor(ultimos[-window:], dtype=torch.float32, device=device).unsqueeze(0)
            pred = model(inp).item()
            preds.append(int(round(pred)))
            ultimos.append(pred)
    return preds

# ================================
# Wrapper de previsão por produto/pdv
# ================================
def prever_grupo(produto, pdv, grupo, model):
    serie = grupo["quantity_smooth"].fillna(method="ffill").dropna().tolist()
    if len(serie) < MIN_SEMANAS_MLP:
        return []  # Ignora séries curtas

    previsoes = prever_mlp(model, serie)
    return [
        {"semana": i+1, "pdv": pdv, "produto": produto, "quantidade": q}
        for i, q in enumerate(previsoes)
    ]

# ================================
# Execução principal
# ================================
if __name__ == "__main__":
    df = carregar_dados()

    # Carregar modelo MLP treinado
    window = joblib.load("mlp_global_metadata.pkl")["window"]
    model = MLP(window).to(device)
    model.load_state_dict(torch.load("mlp_global_2022.pth"))
    model.eval()

    # Remover batches antigos
    for f in glob.glob(f"{OUTPUT_PREFIX}_*.parquet"):
        os.remove(f)

    resultados, batch_idx = [], 0
    start_time = time.time()

    grupos_iter = df.groupby(["produto", "pdv"])
    total = len(grupos_iter)

    # Loop sequencial sem multiprocessamento
    for idx, ((produto, pdv), grupo) in enumerate(grupos_iter, start=1):
        try:
            previsoes = prever_grupo(produto, pdv, grupo, model)
            resultados.extend(previsoes)
        except Exception as e:
            print(f"Erro em {produto}, {pdv}: {e}")

        # Salvar batch
        if len(resultados) >= BATCH_SIZE:
            batch_idx += 1
            batch_file = f"{OUTPUT_PREFIX}_{batch_idx}.parquet"
            pd.DataFrame(resultados).to_parquet(batch_file, index=False, engine="pyarrow")
            resultados = []

        # ETA simples
        if idx % 1000 == 0 or idx == total:
            elapsed = time.time() - start_time
            rate = idx / elapsed if elapsed > 0 else 0.1
            eta = (total - idx) / rate if rate > 0 else 0
            print(f"{idx}/{total} combos processados, ETA ≈ {int(eta//3600)}h {int((eta%3600)//60)}m {int(eta%60)}s")

    # Salvar últimos resultados
    if resultados:
        batch_idx += 1
        batch_file = f"{OUTPUT_PREFIX}_{batch_idx}.parquet"
        pd.DataFrame(resultados).to_parquet(batch_file, index=False, engine="pyarrow")

    # Concatenar todos os batches
    all_files = sorted(glob.glob(f"{OUTPUT_PREFIX}_*.parquet"))
    df_final = pd.concat([pd.read_parquet(f) for f in all_files], ignore_index=True)
    df_final.to_parquet("previsoes_2023_mlp.parquet", index=False, engine="pyarrow")

    print("✅ Arquivo 'previsoes_2023_mlp.parquet' gerado com sucesso!")
    print(df_final.head(20))
# Out:
# 🚀 Usando dispositivo: cuda
# 1000/1044310 combos processados, ETA ≈ 6h 37m 0s
# 2000/1044310 combos processados, ETA ≈ 3h 30m 23s
# 3000/1044310 combos processados, ETA ≈ 2h 25m 1s
# 4000/1044310 combos processados, ETA ≈ 1h 52m 33s
# 5000/1044310 combos processados, ETA ≈ 1h 36m 7s
# 6000/1044310 combos processados, ETA ≈ 1h 25m 34s
# 7000/1044310 combos processados, ETA ≈ 1h 17m 30s
# 8000/1044310 combos processados, ETA ≈ 1h 11m 46s
# 9000/1044310 combos processados, ETA ≈ 1h 6m 52s
# 10000/1044310 combos processados, ETA ≈ 1h 1m 3s
# 11000/1044310 combos processados, ETA ≈ 0h 55m 55s
# 12000/1044310 combos processados, ETA ≈ 0h 52m 38s
# 13000/1044310 combos processados, ETA ≈ 0h 49m 44s
# 14000/1044310 combos processados, ETA ≈ 0h 46m 58s
# 15000/1044310 combos processados, ETA ≈ 0h 45m 24s
# 16000/1044310 combos processados, ETA ≈ 0h 42m 49s
# 17000/1044310 combos processados, ETA ≈ 0h 40m 31s
# 18000/1044310 combos processados, ETA ≈ 0h 38m 28s
# 19000/1044310 combos processados, ETA ≈ 0h 36m 59s
# 20000/1044310 combos processados, ETA ≈ 0h 36m 8s
# 21000/1044310 combos processados, ETA ≈ 0h 34m 51s
# 22000/1044310 combos processados, ETA ≈ 0h 34m 4s
# 23000/1044310 combos processados, ETA ≈ 0h 33m 31s
# 24000/1044310 combos processados, ETA ≈ 0h 32m 54s
# 25000/1044310 combos processados, ETA ≈ 0h 32m 27s
# 26000/1044310 combos processados, ETA ≈ 0h 32m 1s
# 27000/1044310 combos processados, ETA ≈ 0h 31m 22s
# 28000/1044310 combos processados, ETA ≈ 0h 30m 51s
# 29000/1044310 combos processados, ETA ≈ 0h 29m 58s
# 30000/1044310 combos processados, ETA ≈ 0h 29m 14s
# 31000/1044310 combos processados, ETA ≈ 0h 28m 47s
# 32000/1044310 combos processados, ETA ≈ 0h 28m 18s
# 33000/1044310 combos processados, ETA ≈ 0h 27m 38s
# 34000/1044310 combos processados, ETA ≈ 0h 27m 0s
# 35000/1044310 combos processados, ETA ≈ 0h 26m 22s
# 36000/1044310 combos processados, ETA ≈ 0h 26m 15s
# 37000/1044310 combos processados, ETA ≈ 0h 26m 10s
# 38000/1044310 combos processados, ETA ≈ 0h 26m 1s
# 39000/1044310 combos processados, ETA ≈ 0h 25m 35s
# 40000/1044310 combos processados, ETA ≈ 0h 25m 11s
# 41000/1044310 combos processados, ETA ≈ 0h 24m 56s
# 42000/1044310 combos processados, ETA ≈ 0h 24m 42s
# 43000/1044310 combos processados, ETA ≈ 0h 24m 31s
# 44000/1044310 combos processados, ETA ≈ 0h 24m 22s
# 45000/1044310 combos processados, ETA ≈ 0h 24m 1s
# 46000/1044310 combos processados, ETA ≈ 0h 23m 34s
# 47000/1044310 combos processados, ETA ≈ 0h 23m 19s
# 48000/1044310 combos processados, ETA ≈ 0h 23m 17s
# 49000/1044310 combos processados, ETA ≈ 0h 23m 12s
# 50000/1044310 combos processados, ETA ≈ 0h 23m 6s
# 51000/1044310 combos processados, ETA ≈ 0h 23m 1s
# 52000/1044310 combos processados, ETA ≈ 0h 22m 57s
# 53000/1044310 combos processados, ETA ≈ 0h 22m 43s
# 54000/1044310 combos processados, ETA ≈ 0h 22m 21s
# 55000/1044310 combos processados, ETA ≈ 0h 22m 2s
# 56000/1044310 combos processados, ETA ≈ 0h 21m 42s
# 57000/1044310 combos processados, ETA ≈ 0h 21m 25s
# 58000/1044310 combos processados, ETA ≈ 0h 21m 23s
# 59000/1044310 combos processados, ETA ≈ 0h 21m 30s
# 60000/1044310 combos processados, ETA ≈ 0h 21m 13s
# 61000/1044310 combos processados, ETA ≈ 0h 21m 5s
# 62000/1044310 combos processados, ETA ≈ 0h 21m 4s
# 63000/1044310 combos processados, ETA ≈ 0h 21m 1s
# 64000/1044310 combos processados, ETA ≈ 0h 20m 58s
# 65000/1044310 combos processados, ETA ≈ 0h 20m 41s
# 66000/1044310 combos processados, ETA ≈ 0h 20m 25s
# 67000/1044310 combos processados, ETA ≈ 0h 20m 12s
# 68000/1044310 combos processados, ETA ≈ 0h 20m 4s
# 69000/1044310 combos processados, ETA ≈ 0h 19m 50s
# 70000/1044310 combos processados, ETA ≈ 0h 19m 36s
# 71000/1044310 combos processados, ETA ≈ 0h 19m 29s
# 72000/1044310 combos processados, ETA ≈ 0h 19m 21s
# 73000/1044310 combos processados, ETA ≈ 0h 19m 11s
# 74000/1044310 combos processados, ETA ≈ 0h 19m 6s
# 75000/1044310 combos processados, ETA ≈ 0h 18m 54s
# 76000/1044310 combos processados, ETA ≈ 0h 18m 43s
# 77000/1044310 combos processados, ETA ≈ 0h 18m 32s
# 78000/1044310 combos processados, ETA ≈ 0h 18m 22s
# 79000/1044310 combos processados, ETA ≈ 0h 18m 24s
# 80000/1044310 combos processados, ETA ≈ 0h 18m 24s
# 81000/1044310 combos processados, ETA ≈ 0h 18m 28s
# 82000/1044310 combos processados, ETA ≈ 0h 18m 30s
# 83000/1044310 combos processados, ETA ≈ 0h 18m 27s
# 84000/1044310 combos processados, ETA ≈ 0h 18m 20s
# 85000/1044310 combos processados, ETA ≈ 0h 18m 9s
# 86000/1044310 combos processados, ETA ≈ 0h 18m 5s
# 87000/1044310 combos processados, ETA ≈ 0h 17m 56s
# 88000/1044310 combos processados, ETA ≈ 0h 17m 49s
# 89000/1044310 combos processados, ETA ≈ 0h 17m 44s
# 90000/1044310 combos processados, ETA ≈ 0h 17m 34s
# 91000/1044310 combos processados, ETA ≈ 0h 17m 28s
# 92000/1044310 combos processados, ETA ≈ 0h 17m 20s
# 93000/1044310 combos processados, ETA ≈ 0h 17m 18s
# 94000/1044310 combos processados, ETA ≈ 0h 17m 8s
# 95000/1044310 combos processados, ETA ≈ 0h 17m 1s
# 96000/1044310 combos processados, ETA ≈ 0h 16m 59s
# 97000/1044310 combos processados, ETA ≈ 0h 16m 52s
# 98000/1044310 combos processados, ETA ≈ 0h 16m 47s
# 99000/1044310 combos processados, ETA ≈ 0h 16m 38s
# 100000/1044310 combos processados, ETA ≈ 0h 16m 32s
# 101000/1044310 combos processados, ETA ≈ 0h 16m 28s
# 102000/1044310 combos processados, ETA ≈ 0h 16m 23s
# 103000/1044310 combos processados, ETA ≈ 0h 16m 20s
# 104000/1044310 combos processados, ETA ≈ 0h 16m 15s
# 105000/1044310 combos processados, ETA ≈ 0h 16m 7s
# 106000/1044310 combos processados, ETA ≈ 0h 16m 2s
# 107000/1044310 combos processados, ETA ≈ 0h 16m 1s
# 108000/1044310 combos processados, ETA ≈ 0h 16m 0s
# 109000/1044310 combos processados, ETA ≈ 0h 16m 3s
# 110000/1044310 combos processados, ETA ≈ 0h 16m 6s
# 111000/1044310 combos processados, ETA ≈ 0h 16m 5s
# 112000/1044310 combos processados, ETA ≈ 0h 15m 57s
# 113000/1044310 combos processados, ETA ≈ 0h 15m 50s
# 114000/1044310 combos processados, ETA ≈ 0h 15m 45s
# 115000/1044310 combos processados, ETA ≈ 0h 15m 41s
# 116000/1044310 combos processados, ETA ≈ 0h 15m 35s
# 117000/1044310 combos processados, ETA ≈ 0h 15m 28s
# 118000/1044310 combos processados, ETA ≈ 0h 15m 22s
# 119000/1044310 combos processados, ETA ≈ 0h 15m 19s
# 120000/1044310 combos processados, ETA ≈ 0h 15m 14s
# 121000/1044310 combos processados, ETA ≈ 0h 15m 9s
# 122000/1044310 combos processados, ETA ≈ 0h 15m 4s
# 123000/1044310 combos processados, ETA ≈ 0h 14m 58s
# 124000/1044310 combos processados, ETA ≈ 0h 14m 53s
# 125000/1044310 combos processados, ETA ≈ 0h 14m 52s
# 126000/1044310 combos processados, ETA ≈ 0h 14m 55s
# 127000/1044310 combos processados, ETA ≈ 0h 14m 52s
# 128000/1044310 combos processados, ETA ≈ 0h 14m 47s
# 129000/1044310 combos processados, ETA ≈ 0h 14m 43s
# 130000/1044310 combos processados, ETA ≈ 0h 14m 45s
# 131000/1044310 combos processados, ETA ≈ 0h 14m 47s
# 132000/1044310 combos processados, ETA ≈ 0h 14m 48s
# 133000/1044310 combos processados, ETA ≈ 0h 14m 42s
# 134000/1044310 combos processados, ETA ≈ 0h 14m 37s
# 135000/1044310 combos processados, ETA ≈ 0h 14m 33s
# 136000/1044310 combos processados, ETA ≈ 0h 14m 27s
# 137000/1044310 combos processados, ETA ≈ 0h 14m 22s
# 138000/1044310 combos processados, ETA ≈ 0h 14m 18s
# 139000/1044310 combos processados, ETA ≈ 0h 14m 20s
# 140000/1044310 combos processados, ETA ≈ 0h 14m 18s
# 141000/1044310 combos processados, ETA ≈ 0h 14m 16s
# 142000/1044310 combos processados, ETA ≈ 0h 14m 20s
# 143000/1044310 combos processados, ETA ≈ 0h 14m 24s
# 144000/1044310 combos processados, ETA ≈ 0h 14m 23s
# 145000/1044310 combos processados, ETA ≈ 0h 14m 18s
# 146000/1044310 combos processados, ETA ≈ 0h 14m 13s
# 147000/1044310 combos processados, ETA ≈ 0h 14m 8s
# 148000/1044310 combos processados, ETA ≈ 0h 14m 3s
# 149000/1044310 combos processados, ETA ≈ 0h 13m 58s
# 150000/1044310 combos processados, ETA ≈ 0h 13m 53s
# 151000/1044310 combos processados, ETA ≈ 0h 13m 50s
# 152000/1044310 combos processados, ETA ≈ 0h 13m 49s
# 153000/1044310 combos processados, ETA ≈ 0h 13m 49s
# 154000/1044310 combos processados, ETA ≈ 0h 13m 48s
# 155000/1044310 combos processados, ETA ≈ 0h 13m 49s
# 156000/1044310 combos processados, ETA ≈ 0h 13m 49s
# 157000/1044310 combos processados, ETA ≈ 0h 13m 44s
# 158000/1044310 combos processados, ETA ≈ 0h 13m 40s
# 159000/1044310 combos processados, ETA ≈ 0h 13m 37s
# 160000/1044310 combos processados, ETA ≈ 0h 13m 33s
# 161000/1044310 combos processados, ETA ≈ 0h 13m 34s
# 162000/1044310 combos processados, ETA ≈ 0h 13m 38s
# 163000/1044310 combos processados, ETA ≈ 0h 13m 39s
# 164000/1044310 combos processados, ETA ≈ 0h 13m 35s
# 165000/1044310 combos processados, ETA ≈ 0h 13m 31s
# 166000/1044310 combos processados, ETA ≈ 0h 13m 28s
# 167000/1044310 combos processados, ETA ≈ 0h 13m 28s
# 168000/1044310 combos processados, ETA ≈ 0h 13m 26s
# 169000/1044310 combos processados, ETA ≈ 0h 13m 24s
# 170000/1044310 combos processados, ETA ≈ 0h 13m 22s
# 171000/1044310 combos processados, ETA ≈ 0h 13m 17s
# 172000/1044310 combos processados, ETA ≈ 0h 13m 14s
# 173000/1044310 combos processados, ETA ≈ 0h 13m 10s
# 174000/1044310 combos processados, ETA ≈ 0h 13m 7s
# 175000/1044310 combos processados, ETA ≈ 0h 13m 3s
# 176000/1044310 combos processados, ETA ≈ 0h 13m 0s
# 177000/1044310 combos processados, ETA ≈ 0h 13m 3s
# 178000/1044310 combos processados, ETA ≈ 0h 13m 6s
# 179000/1044310 combos processados, ETA ≈ 0h 13m 4s
# 180000/1044310 combos processados, ETA ≈ 0h 13m 0s
# 181000/1044310 combos processados, ETA ≈ 0h 12m 56s
# 182000/1044310 combos processados, ETA ≈ 0h 12m 54s
# 183000/1044310 combos processados, ETA ≈ 0h 12m 55s
# 184000/1044310 combos processados, ETA ≈ 0h 12m 52s
# 185000/1044310 combos processados, ETA ≈ 0h 12m 49s
# 186000/1044310 combos processados, ETA ≈ 0h 12m 46s
# 187000/1044310 combos processados, ETA ≈ 0h 12m 42s
# 188000/1044310 combos processados, ETA ≈ 0h 12m 38s
# 189000/1044310 combos processados, ETA ≈ 0h 12m 38s
# 190000/1044310 combos processados, ETA ≈ 0h 12m 39s
# 191000/1044310 combos processados, ETA ≈ 0h 12m 36s
# 192000/1044310 combos processados, ETA ≈ 0h 12m 33s
# 193000/1044310 combos processados, ETA ≈ 0h 12m 30s
# 194000/1044310 combos processados, ETA ≈ 0h 12m 27s
# 195000/1044310 combos processados, ETA ≈ 0h 12m 24s
# 196000/1044310 combos processados, ETA ≈ 0h 12m 20s
# 197000/1044310 combos processados, ETA ≈ 0h 12m 19s
# 198000/1044310 combos processados, ETA ≈ 0h 12m 16s
# 199000/1044310 combos processados, ETA ≈ 0h 12m 12s
# 200000/1044310 combos processados, ETA ≈ 0h 12m 9s
# 201000/1044310 combos processados, ETA ≈ 0h 12m 8s
# 202000/1044310 combos processados, ETA ≈ 0h 12m 7s
# 203000/1044310 combos processados, ETA ≈ 0h 12m 7s
# 204000/1044310 combos processados, ETA ≈ 0h 12m 6s
# 205000/1044310 combos processados, ETA ≈ 0h 12m 5s
# 206000/1044310 combos processados, ETA ≈ 0h 12m 2s
# 207000/1044310 combos processados, ETA ≈ 0h 12m 0s
# 208000/1044310 combos processados, ETA ≈ 0h 11m 58s
# 209000/1044310 combos processados, ETA ≈ 0h 11m 56s
# 210000/1044310 combos processados, ETA ≈ 0h 11m 54s
# 211000/1044310 combos processados, ETA ≈ 0h 11m 51s
# 212000/1044310 combos processados, ETA ≈ 0h 11m 50s
# 213000/1044310 combos processados, ETA ≈ 0h 11m 50s
# 214000/1044310 combos processados, ETA ≈ 0h 11m 51s
# 215000/1044310 combos processados, ETA ≈ 0h 11m 48s
# 216000/1044310 combos processados, ETA ≈ 0h 11m 46s
# 217000/1044310 combos processados, ETA ≈ 0h 11m 43s
# 218000/1044310 combos processados, ETA ≈ 0h 11m 41s
# 219000/1044310 combos processados, ETA ≈ 0h 11m 40s
# 220000/1044310 combos processados, ETA ≈ 0h 11m 39s
# 221000/1044310 combos processados, ETA ≈ 0h 11m 37s
# 222000/1044310 combos processados, ETA ≈ 0h 11m 35s
# 223000/1044310 combos processados, ETA ≈ 0h 11m 37s
# 224000/1044310 combos processados, ETA ≈ 0h 11m 35s
# 225000/1044310 combos processados, ETA ≈ 0h 11m 32s
# 226000/1044310 combos processados, ETA ≈ 0h 11m 29s
# 227000/1044310 combos processados, ETA ≈ 0h 11m 27s
# 228000/1044310 combos processados, ETA ≈ 0h 11m 28s
# 229000/1044310 combos processados, ETA ≈ 0h 11m 26s
# 230000/1044310 combos processados, ETA ≈ 0h 11m 23s
# 231000/1044310 combos processados, ETA ≈ 0h 11m 22s
# 232000/1044310 combos processados, ETA ≈ 0h 11m 19s
# 233000/1044310 combos processados, ETA ≈ 0h 11m 17s
# 234000/1044310 combos processados, ETA ≈ 0h 11m 14s
# 235000/1044310 combos processados, ETA ≈ 0h 11m 11s
# 236000/1044310 combos processados, ETA ≈ 0h 11m 9s
# 237000/1044310 combos processados, ETA ≈ 0h 11m 7s
# 238000/1044310 combos processados, ETA ≈ 0h 11m 6s
# 239000/1044310 combos processados, ETA ≈ 0h 11m 4s
# 240000/1044310 combos processados, ETA ≈ 0h 11m 3s
# 241000/1044310 combos processados, ETA ≈ 0h 11m 0s
# 242000/1044310 combos processados, ETA ≈ 0h 10m 59s
# 243000/1044310 combos processados, ETA ≈ 0h 10m 59s
# 244000/1044310 combos processados, ETA ≈ 0h 10m 58s
# 245000/1044310 combos processados, ETA ≈ 0h 10m 56s
# 246000/1044310 combos processados, ETA ≈ 0h 10m 54s
# 247000/1044310 combos processados, ETA ≈ 0h 10m 52s
# 248000/1044310 combos processados, ETA ≈ 0h 10m 49s
# 249000/1044310 combos processados, ETA ≈ 0h 10m 47s
# 250000/1044310 combos processados, ETA ≈ 0h 10m 45s
# 251000/1044310 combos processados, ETA ≈ 0h 10m 43s
# 252000/1044310 combos processados, ETA ≈ 0h 10m 42s
# 253000/1044310 combos processados, ETA ≈ 0h 10m 40s
# 254000/1044310 combos processados, ETA ≈ 0h 10m 37s
# 255000/1044310 combos processados, ETA ≈ 0h 10m 35s
# 256000/1044310 combos processados, ETA ≈ 0h 10m 32s
# 257000/1044310 combos processados, ETA ≈ 0h 10m 31s
# 258000/1044310 combos processados, ETA ≈ 0h 10m 32s
# 259000/1044310 combos processados, ETA ≈ 0h 10m 34s
# 260000/1044310 combos processados, ETA ≈ 0h 10m 35s
# 261000/1044310 combos processados, ETA ≈ 0h 10m 34s
# 262000/1044310 combos processados, ETA ≈ 0h 10m 31s
# 263000/1044310 combos processados, ETA ≈ 0h 10m 29s
# 264000/1044310 combos processados, ETA ≈ 0h 10m 27s
# 265000/1044310 combos processados, ETA ≈ 0h 10m 26s
# 266000/1044310 combos processados, ETA ≈ 0h 10m 26s
# 267000/1044310 combos processados, ETA ≈ 0h 10m 26s
# 268000/1044310 combos processados, ETA ≈ 0h 10m 24s
# 269000/1044310 combos processados, ETA ≈ 0h 10m 22s
# 270000/1044310 combos processados, ETA ≈ 0h 10m 20s
# 271000/1044310 combos processados, ETA ≈ 0h 10m 19s
# 272000/1044310 combos processados, ETA ≈ 0h 10m 18s
# 273000/1044310 combos processados, ETA ≈ 0h 10m 15s
# 274000/1044310 combos processados, ETA ≈ 0h 10m 13s
# 275000/1044310 combos processados, ETA ≈ 0h 10m 11s
# 276000/1044310 combos processados, ETA ≈ 0h 10m 11s
# 277000/1044310 combos processados, ETA ≈ 0h 10m 11s
# 278000/1044310 combos processados, ETA ≈ 0h 10m 10s
# 279000/1044310 combos processados, ETA ≈ 0h 10m 7s
# 280000/1044310 combos processados, ETA ≈ 0h 10m 6s
# 281000/1044310 combos processados, ETA ≈ 0h 10m 4s
# 282000/1044310 combos processados, ETA ≈ 0h 10m 3s
# 283000/1044310 combos processados, ETA ≈ 0h 10m 1s
# 284000/1044310 combos processados, ETA ≈ 0h 10m 1s
# 285000/1044310 combos processados, ETA ≈ 0h 9m 59s
# 286000/1044310 combos processados, ETA ≈ 0h 9m 57s
# 287000/1044310 combos processados, ETA ≈ 0h 9m 57s
# 288000/1044310 combos processados, ETA ≈ 0h 9m 56s
# 289000/1044310 combos processados, ETA ≈ 0h 9m 56s
# 290000/1044310 combos processados, ETA ≈ 0h 9m 57s
# 291000/1044310 combos processados, ETA ≈ 0h 9m 56s
# 292000/1044310 combos processados, ETA ≈ 0h 9m 55s
# 293000/1044310 combos processados, ETA ≈ 0h 9m 54s
# 294000/1044310 combos processados, ETA ≈ 0h 9m 52s
# 295000/1044310 combos processados, ETA ≈ 0h 9m 50s
# 296000/1044310 combos processados, ETA ≈ 0h 9m 48s
# 297000/1044310 combos processados, ETA ≈ 0h 9m 45s
# 298000/1044310 combos processados, ETA ≈ 0h 9m 44s
# 299000/1044310 combos processados, ETA ≈ 0h 9m 43s
# 300000/1044310 combos processados, ETA ≈ 0h 9m 42s
# 301000/1044310 combos processados, ETA ≈ 0h 9m 43s
# 302000/1044310 combos processados, ETA ≈ 0h 9m 44s
# 303000/1044310 combos processados, ETA ≈ 0h 9m 44s
# 304000/1044310 combos processados, ETA ≈ 0h 9m 45s
# 305000/1044310 combos processados, ETA ≈ 0h 9m 45s
# 306000/1044310 combos processados, ETA ≈ 0h 9m 46s
# 307000/1044310 combos processados, ETA ≈ 0h 9m 45s
# 308000/1044310 combos processados, ETA ≈ 0h 9m 45s
# 309000/1044310 combos processados, ETA ≈ 0h 9m 44s
# 310000/1044310 combos processados, ETA ≈ 0h 9m 42s
# 311000/1044310 combos processados, ETA ≈ 0h 9m 41s
# 312000/1044310 combos processados, ETA ≈ 0h 9m 40s
# 313000/1044310 combos processados, ETA ≈ 0h 9m 38s
# 314000/1044310 combos processados, ETA ≈ 0h 9m 36s
# 315000/1044310 combos processados, ETA ≈ 0h 9m 34s
# 316000/1044310 combos processados, ETA ≈ 0h 9m 33s
# 317000/1044310 combos processados, ETA ≈ 0h 9m 31s
# 318000/1044310 combos processados, ETA ≈ 0h 9m 29s
# 319000/1044310 combos processados, ETA ≈ 0h 9m 29s
# 320000/1044310 combos processados, ETA ≈ 0h 9m 28s
# 321000/1044310 combos processados, ETA ≈ 0h 9m 27s
# 322000/1044310 combos processados, ETA ≈ 0h 9m 25s
# 323000/1044310 combos processados, ETA ≈ 0h 9m 23s
# 324000/1044310 combos processados, ETA ≈ 0h 9m 21s
# 325000/1044310 combos processados, ETA ≈ 0h 9m 20s
# 326000/1044310 combos processados, ETA ≈ 0h 9m 21s
# 327000/1044310 combos processados, ETA ≈ 0h 9m 22s
# 328000/1044310 combos processados, ETA ≈ 0h 9m 22s
# 329000/1044310 combos processados, ETA ≈ 0h 9m 23s
# 330000/1044310 combos processados, ETA ≈ 0h 9m 21s
# 331000/1044310 combos processados, ETA ≈ 0h 9m 19s
# 332000/1044310 combos processados, ETA ≈ 0h 9m 19s
# 333000/1044310 combos processados, ETA ≈ 0h 9m 18s
# 334000/1044310 combos processados, ETA ≈ 0h 9m 17s
# 335000/1044310 combos processados, ETA ≈ 0h 9m 15s
# 336000/1044310 combos processados, ETA ≈ 0h 9m 14s
# 337000/1044310 combos processados, ETA ≈ 0h 9m 13s
# 338000/1044310 combos processados, ETA ≈ 0h 9m 12s
# 339000/1044310 combos processados, ETA ≈ 0h 9m 11s
# 340000/1044310 combos processados, ETA ≈ 0h 9m 10s
# 341000/1044310 combos processados, ETA ≈ 0h 9m 9s
# 342000/1044310 combos processados, ETA ≈ 0h 9m 8s
# 343000/1044310 combos processados, ETA ≈ 0h 9m 7s
# 344000/1044310 combos processados, ETA ≈ 0h 9m 6s
# 345000/1044310 combos processados, ETA ≈ 0h 9m 6s
# 346000/1044310 combos processados, ETA ≈ 0h 9m 7s
# 347000/1044310 combos processados, ETA ≈ 0h 9m 7s
# 348000/1044310 combos processados, ETA ≈ 0h 9m 7s
# 349000/1044310 combos processados, ETA ≈ 0h 9m 5s
# 350000/1044310 combos processados, ETA ≈ 0h 9m 3s
# 351000/1044310 combos processados, ETA ≈ 0h 9m 1s
# 352000/1044310 combos processados, ETA ≈ 0h 9m 0s
# 353000/1044310 combos processados, ETA ≈ 0h 8m 58s
# 354000/1044310 combos processados, ETA ≈ 0h 8m 57s
# 355000/1044310 combos processados, ETA ≈ 0h 8m 56s
# 356000/1044310 combos processados, ETA ≈ 0h 8m 54s
# 357000/1044310 combos processados, ETA ≈ 0h 8m 52s
# 358000/1044310 combos processados, ETA ≈ 0h 8m 51s
# 359000/1044310 combos processados, ETA ≈ 0h 8m 49s
# 360000/1044310 combos processados, ETA ≈ 0h 8m 47s
# 361000/1044310 combos processados, ETA ≈ 0h 8m 46s
# 362000/1044310 combos processados, ETA ≈ 0h 8m 44s
# 363000/1044310 combos processados, ETA ≈ 0h 8m 44s
# 364000/1044310 combos processados, ETA ≈ 0h 8m 43s
# 365000/1044310 combos processados, ETA ≈ 0h 8m 42s
# 366000/1044310 combos processados, ETA ≈ 0h 8m 40s
# 367000/1044310 combos processados, ETA ≈ 0h 8m 39s
# 368000/1044310 combos processados, ETA ≈ 0h 8m 38s
# 369000/1044310 combos processados, ETA ≈ 0h 8m 37s
# 370000/1044310 combos processados, ETA ≈ 0h 8m 35s
# 371000/1044310 combos processados, ETA ≈ 0h 8m 34s
# 372000/1044310 combos processados, ETA ≈ 0h 8m 33s
# 373000/1044310 combos processados, ETA ≈ 0h 8m 31s
# 374000/1044310 combos processados, ETA ≈ 0h 8m 30s
# 375000/1044310 combos processados, ETA ≈ 0h 8m 28s
# 376000/1044310 combos processados, ETA ≈ 0h 8m 27s
# 377000/1044310 combos processados, ETA ≈ 0h 8m 26s
# 378000/1044310 combos processados, ETA ≈ 0h 8m 27s
# 379000/1044310 combos processados, ETA ≈ 0h 8m 26s
# 380000/1044310 combos processados, ETA ≈ 0h 8m 24s
# 381000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 382000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 383000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 384000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 385000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 386000/1044310 combos processados, ETA ≈ 0h 8m 25s
# 387000/1044310 combos processados, ETA ≈ 0h 8m 27s
# 388000/1044310 combos processados, ETA ≈ 0h 8m 26s
# 389000/1044310 combos processados, ETA ≈ 0h 8m 26s
# 390000/1044310 combos processados, ETA ≈ 0h 8m 26s
# 391000/1044310 combos processados, ETA ≈ 0h 8m 24s
# 392000/1044310 combos processados, ETA ≈ 0h 8m 23s
# 393000/1044310 combos processados, ETA ≈ 0h 8m 22s
# 394000/1044310 combos processados, ETA ≈ 0h 8m 20s
# 395000/1044310 combos processados, ETA ≈ 0h 8m 19s
# 396000/1044310 combos processados, ETA ≈ 0h 8m 20s
# 397000/1044310 combos processados, ETA ≈ 0h 8m 21s
# 398000/1044310 combos processados, ETA ≈ 0h 8m 21s
# 399000/1044310 combos processados, ETA ≈ 0h 8m 20s
# 400000/1044310 combos processados, ETA ≈ 0h 8m 18s
# 401000/1044310 combos processados, ETA ≈ 0h 8m 17s
# 402000/1044310 combos processados, ETA ≈ 0h 8m 17s
# 403000/1044310 combos processados, ETA ≈ 0h 8m 17s
# 404000/1044310 combos processados, ETA ≈ 0h 8m 17s
# 405000/1044310 combos processados, ETA ≈ 0h 8m 18s
# 406000/1044310 combos processados, ETA ≈ 0h 8m 19s
# 407000/1044310 combos processados, ETA ≈ 0h 8m 17s
# 408000/1044310 combos processados, ETA ≈ 0h 8m 16s
# 409000/1044310 combos processados, ETA ≈ 0h 8m 14s
# 410000/1044310 combos processados, ETA ≈ 0h 8m 13s
# 411000/1044310 combos processados, ETA ≈ 0h 8m 12s
# 412000/1044310 combos processados, ETA ≈ 0h 8m 12s
# 413000/1044310 combos processados, ETA ≈ 0h 8m 12s
# 414000/1044310 combos processados, ETA ≈ 0h 8m 12s
# 415000/1044310 combos processados, ETA ≈ 0h 8m 11s
# 416000/1044310 combos processados, ETA ≈ 0h 8m 11s
# 417000/1044310 combos processados, ETA ≈ 0h 8m 11s
# 418000/1044310 combos processados, ETA ≈ 0h 8m 10s
# 419000/1044310 combos processados, ETA ≈ 0h 8m 8s
# 420000/1044310 combos processados, ETA ≈ 0h 8m 7s
# 421000/1044310 combos processados, ETA ≈ 0h 8m 5s
# 422000/1044310 combos processados, ETA ≈ 0h 8m 4s
# 423000/1044310 combos processados, ETA ≈ 0h 8m 2s
# 424000/1044310 combos processados, ETA ≈ 0h 8m 1s
# 425000/1044310 combos processados, ETA ≈ 0h 7m 59s
# 426000/1044310 combos processados, ETA ≈ 0h 7m 58s
# 427000/1044310 combos processados, ETA ≈ 0h 7m 57s
# 428000/1044310 combos processados, ETA ≈ 0h 7m 56s
# 429000/1044310 combos processados, ETA ≈ 0h 7m 55s
# 430000/1044310 combos processados, ETA ≈ 0h 7m 54s
# 431000/1044310 combos processados, ETA ≈ 0h 7m 52s
# 432000/1044310 combos processados, ETA ≈ 0h 7m 51s
# 433000/1044310 combos processados, ETA ≈ 0h 7m 51s
# 434000/1044310 combos processados, ETA ≈ 0h 7m 49s
# 435000/1044310 combos processados, ETA ≈ 0h 7m 48s
# 436000/1044310 combos processados, ETA ≈ 0h 7m 47s
# 437000/1044310 combos processados, ETA ≈ 0h 7m 45s
# 438000/1044310 combos processados, ETA ≈ 0h 7m 44s
# 439000/1044310 combos processados, ETA ≈ 0h 7m 43s
# 440000/1044310 combos processados, ETA ≈ 0h 7m 42s
# 441000/1044310 combos processados, ETA ≈ 0h 7m 41s
# 442000/1044310 combos processados, ETA ≈ 0h 7m 39s
# 443000/1044310 combos processados, ETA ≈ 0h 7m 38s
# 444000/1044310 combos processados, ETA ≈ 0h 7m 37s
# 445000/1044310 combos processados, ETA ≈ 0h 7m 36s
# 446000/1044310 combos processados, ETA ≈ 0h 7m 35s
# 447000/1044310 combos processados, ETA ≈ 0h 7m 34s
# 448000/1044310 combos processados, ETA ≈ 0h 7m 34s
# 449000/1044310 combos processados, ETA ≈ 0h 7m 32s
# 450000/1044310 combos processados, ETA ≈ 0h 7m 31s
# 451000/1044310 combos processados, ETA ≈ 0h 7m 30s
# 452000/1044310 combos processados, ETA ≈ 0h 7m 30s
# 453000/1044310 combos processados, ETA ≈ 0h 7m 29s
# 454000/1044310 combos processados, ETA ≈ 0h 7m 29s
# 455000/1044310 combos processados, ETA ≈ 0h 7m 29s
# 456000/1044310 combos processados, ETA ≈ 0h 7m 29s
# 457000/1044310 combos processados, ETA ≈ 0h 7m 28s
# 458000/1044310 combos processados, ETA ≈ 0h 7m 27s
# 459000/1044310 combos processados, ETA ≈ 0h 7m 26s
# 460000/1044310 combos processados, ETA ≈ 0h 7m 25s
# 461000/1044310 combos processados, ETA ≈ 0h 7m 24s
# 462000/1044310 combos processados, ETA ≈ 0h 7m 23s
# 463000/1044310 combos processados, ETA ≈ 0h 7m 21s
# 464000/1044310 combos processados, ETA ≈ 0h 7m 21s
# 465000/1044310 combos processados, ETA ≈ 0h 7m 20s
# 466000/1044310 combos processados, ETA ≈ 0h 7m 19s
# 467000/1044310 combos processados, ETA ≈ 0h 7m 18s
# 468000/1044310 combos processados, ETA ≈ 0h 7m 18s
# 469000/1044310 combos processados, ETA ≈ 0h 7m 19s
# 470000/1044310 combos processados, ETA ≈ 0h 7m 19s
# 471000/1044310 combos processados, ETA ≈ 0h 7m 19s
# 472000/1044310 combos processados, ETA ≈ 0h 7m 18s
# 473000/1044310 combos processados, ETA ≈ 0h 7m 18s
# 474000/1044310 combos processados, ETA ≈ 0h 7m 17s
# 475000/1044310 combos processados, ETA ≈ 0h 7m 17s
# 476000/1044310 combos processados, ETA ≈ 0h 7m 15s
# 477000/1044310 combos processados, ETA ≈ 0h 7m 14s
# 478000/1044310 combos processados, ETA ≈ 0h 7m 13s
# 479000/1044310 combos processados, ETA ≈ 0h 7m 13s
# 480000/1044310 combos processados, ETA ≈ 0h 7m 11s
# 481000/1044310 combos processados, ETA ≈ 0h 7m 10s
# 482000/1044310 combos processados, ETA ≈ 0h 7m 9s
# 483000/1044310 combos processados, ETA ≈ 0h 7m 8s
# 484000/1044310 combos processados, ETA ≈ 0h 7m 6s
# 485000/1044310 combos processados, ETA ≈ 0h 7m 5s
# 486000/1044310 combos processados, ETA ≈ 0h 7m 4s
# 487000/1044310 combos processados, ETA ≈ 0h 7m 4s
# 488000/1044310 combos processados, ETA ≈ 0h 7m 5s
# 489000/1044310 combos processados, ETA ≈ 0h 7m 5s
# 490000/1044310 combos processados, ETA ≈ 0h 7m 4s
# 491000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 492000/1044310 combos processados, ETA ≈ 0h 7m 2s
# 493000/1044310 combos processados, ETA ≈ 0h 7m 2s
# 494000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 495000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 496000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 497000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 498000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 499000/1044310 combos processados, ETA ≈ 0h 7m 3s
# 500000/1044310 combos processados, ETA ≈ 0h 7m 1s
# 501000/1044310 combos processados, ETA ≈ 0h 7m 0s
# 502000/1044310 combos processados, ETA ≈ 0h 6m 59s
# 503000/1044310 combos processados, ETA ≈ 0h 6m 58s
# 504000/1044310 combos processados, ETA ≈ 0h 6m 57s
# 505000/1044310 combos processados, ETA ≈ 0h 6m 56s
# 506000/1044310 combos processados, ETA ≈ 0h 6m 55s
# 507000/1044310 combos processados, ETA ≈ 0h 6m 54s
# 508000/1044310 combos processados, ETA ≈ 0h 6m 54s
# 509000/1044310 combos processados, ETA ≈ 0h 6m 54s
# 510000/1044310 combos processados, ETA ≈ 0h 6m 53s
# 511000/1044310 combos processados, ETA ≈ 0h 6m 53s
# 512000/1044310 combos processados, ETA ≈ 0h 6m 53s
# 513000/1044310 combos processados, ETA ≈ 0h 6m 52s
# 514000/1044310 combos processados, ETA ≈ 0h 6m 50s
# 515000/1044310 combos processados, ETA ≈ 0h 6m 49s
# 516000/1044310 combos processados, ETA ≈ 0h 6m 48s
# 517000/1044310 combos processados, ETA ≈ 0h 6m 47s
# 518000/1044310 combos processados, ETA ≈ 0h 6m 46s
# 519000/1044310 combos processados, ETA ≈ 0h 6m 44s
# 520000/1044310 combos processados, ETA ≈ 0h 6m 44s
# 521000/1044310 combos processados, ETA ≈ 0h 6m 43s
# 522000/1044310 combos processados, ETA ≈ 0h 6m 42s
# 523000/1044310 combos processados, ETA ≈ 0h 6m 41s
# 524000/1044310 combos processados, ETA ≈ 0h 6m 39s
# 525000/1044310 combos processados, ETA ≈ 0h 6m 38s
# 526000/1044310 combos processados, ETA ≈ 0h 6m 37s
# 527000/1044310 combos processados, ETA ≈ 0h 6m 36s
# 528000/1044310 combos processados, ETA ≈ 0h 6m 35s
# 529000/1044310 combos processados, ETA ≈ 0h 6m 34s
# 530000/1044310 combos processados, ETA ≈ 0h 6m 33s
# 531000/1044310 combos processados, ETA ≈ 0h 6m 32s
# 532000/1044310 combos processados, ETA ≈ 0h 6m 32s
# 533000/1044310 combos processados, ETA ≈ 0h 6m 31s
# 534000/1044310 combos processados, ETA ≈ 0h 6m 29s
# 535000/1044310 combos processados, ETA ≈ 0h 6m 28s
# 536000/1044310 combos processados, ETA ≈ 0h 6m 27s
# 537000/1044310 combos processados, ETA ≈ 0h 6m 26s
# 538000/1044310 combos processados, ETA ≈ 0h 6m 25s
# 539000/1044310 combos processados, ETA ≈ 0h 6m 24s
# 540000/1044310 combos processados, ETA ≈ 0h 6m 24s
# 541000/1044310 combos processados, ETA ≈ 0h 6m 23s
# 542000/1044310 combos processados, ETA ≈ 0h 6m 22s
# 543000/1044310 combos processados, ETA ≈ 0h 6m 21s
# 544000/1044310 combos processados, ETA ≈ 0h 6m 21s
# 545000/1044310 combos processados, ETA ≈ 0h 6m 20s
# 546000/1044310 combos processados, ETA ≈ 0h 6m 19s
# 547000/1044310 combos processados, ETA ≈ 0h 6m 18s
# 548000/1044310 combos processados, ETA ≈ 0h 6m 18s
# 549000/1044310 combos processados, ETA ≈ 0h 6m 18s
# 550000/1044310 combos processados, ETA ≈ 0h 6m 18s
# 551000/1044310 combos processados, ETA ≈ 0h 6m 17s
# 552000/1044310 combos processados, ETA ≈ 0h 6m 16s
# 553000/1044310 combos processados, ETA ≈ 0h 6m 14s
# 554000/1044310 combos processados, ETA ≈ 0h 6m 13s
# 555000/1044310 combos processados, ETA ≈ 0h 6m 12s
# 556000/1044310 combos processados, ETA ≈ 0h 6m 11s
# 557000/1044310 combos processados, ETA ≈ 0h 6m 10s
# 558000/1044310 combos processados, ETA ≈ 0h 6m 10s
# 559000/1044310 combos processados, ETA ≈ 0h 6m 9s
# 560000/1044310 combos processados, ETA ≈ 0h 6m 8s
# 561000/1044310 combos processados, ETA ≈ 0h 6m 7s
# 562000/1044310 combos processados, ETA ≈ 0h 6m 6s
# 563000/1044310 combos processados, ETA ≈ 0h 6m 5s
# 564000/1044310 combos processados, ETA ≈ 0h 6m 4s
# 565000/1044310 combos processados, ETA ≈ 0h 6m 3s
# 566000/1044310 combos processados, ETA ≈ 0h 6m 2s
# 567000/1044310 combos processados, ETA ≈ 0h 6m 1s
# 568000/1044310 combos processados, ETA ≈ 0h 6m 0s
# 569000/1044310 combos processados, ETA ≈ 0h 6m 0s
# 570000/1044310 combos processados, ETA ≈ 0h 5m 59s
# 571000/1044310 combos processados, ETA ≈ 0h 5m 58s
# 572000/1044310 combos processados, ETA ≈ 0h 5m 58s
# 573000/1044310 combos processados, ETA ≈ 0h 5m 57s
# 574000/1044310 combos processados, ETA ≈ 0h 5m 56s
# 575000/1044310 combos processados, ETA ≈ 0h 5m 55s
# 576000/1044310 combos processados, ETA ≈ 0h 5m 55s
# 577000/1044310 combos processados, ETA ≈ 0h 5m 53s
# 578000/1044310 combos processados, ETA ≈ 0h 5m 52s
# 579000/1044310 combos processados, ETA ≈ 0h 5m 51s
# 580000/1044310 combos processados, ETA ≈ 0h 5m 50s
# 581000/1044310 combos processados, ETA ≈ 0h 5m 49s
# 582000/1044310 combos processados, ETA ≈ 0h 5m 48s
# 583000/1044310 combos processados, ETA ≈ 0h 5m 47s
# 584000/1044310 combos processados, ETA ≈ 0h 5m 46s
# 585000/1044310 combos processados, ETA ≈ 0h 5m 46s
# 586000/1044310 combos processados, ETA ≈ 0h 5m 44s
# 587000/1044310 combos processados, ETA ≈ 0h 5m 43s
# 588000/1044310 combos processados, ETA ≈ 0h 5m 42s
# 589000/1044310 combos processados, ETA ≈ 0h 5m 41s
# 590000/1044310 combos processados, ETA ≈ 0h 5m 41s
# 591000/1044310 combos processados, ETA ≈ 0h 5m 41s
# 592000/1044310 combos processados, ETA ≈ 0h 5m 40s
# 593000/1044310 combos processados, ETA ≈ 0h 5m 39s
# 594000/1044310 combos processados, ETA ≈ 0h 5m 38s
# 595000/1044310 combos processados, ETA ≈ 0h 5m 37s
# 596000/1044310 combos processados, ETA ≈ 0h 5m 36s
# 597000/1044310 combos processados, ETA ≈ 0h 5m 36s
# 598000/1044310 combos processados, ETA ≈ 0h 5m 35s
# 599000/1044310 combos processados, ETA ≈ 0h 5m 34s
# 600000/1044310 combos processados, ETA ≈ 0h 5m 33s
# 601000/1044310 combos processados, ETA ≈ 0h 5m 33s
# 602000/1044310 combos processados, ETA ≈ 0h 5m 32s
# 603000/1044310 combos processados, ETA ≈ 0h 5m 31s
# 604000/1044310 combos processados, ETA ≈ 0h 5m 30s
# 605000/1044310 combos processados, ETA ≈ 0h 5m 29s
# 606000/1044310 combos processados, ETA ≈ 0h 5m 28s
# 607000/1044310 combos processados, ETA ≈ 0h 5m 27s
# 608000/1044310 combos processados, ETA ≈ 0h 5m 26s
# 609000/1044310 combos processados, ETA ≈ 0h 5m 25s
# 610000/1044310 combos processados, ETA ≈ 0h 5m 24s
# 611000/1044310 combos processados, ETA ≈ 0h 5m 23s
# 612000/1044310 combos processados, ETA ≈ 0h 5m 22s
# 613000/1044310 combos processados, ETA ≈ 0h 5m 21s
# 614000/1044310 combos processados, ETA ≈ 0h 5m 21s
# 615000/1044310 combos processados, ETA ≈ 0h 5m 20s
# 616000/1044310 combos processados, ETA ≈ 0h 5m 19s
# 617000/1044310 combos processados, ETA ≈ 0h 5m 18s
# 618000/1044310 combos processados, ETA ≈ 0h 5m 17s
# 619000/1044310 combos processados, ETA ≈ 0h 5m 16s
# 620000/1044310 combos processados, ETA ≈ 0h 5m 15s
# 621000/1044310 combos processados, ETA ≈ 0h 5m 14s
# 622000/1044310 combos processados, ETA ≈ 0h 5m 13s
# 623000/1044310 combos processados, ETA ≈ 0h 5m 13s
# 624000/1044310 combos processados, ETA ≈ 0h 5m 12s
# 625000/1044310 combos processados, ETA ≈ 0h 5m 11s
# 626000/1044310 combos processados, ETA ≈ 0h 5m 10s
# 627000/1044310 combos processados, ETA ≈ 0h 5m 9s
# 628000/1044310 combos processados, ETA ≈ 0h 5m 8s
# 629000/1044310 combos processados, ETA ≈ 0h 5m 8s
# 630000/1044310 combos processados, ETA ≈ 0h 5m 8s
# 631000/1044310 combos processados, ETA ≈ 0h 5m 7s
# 632000/1044310 combos processados, ETA ≈ 0h 5m 6s
# 633000/1044310 combos processados, ETA ≈ 0h 5m 5s
# 634000/1044310 combos processados, ETA ≈ 0h 5m 4s
# 635000/1044310 combos processados, ETA ≈ 0h 5m 3s
# 636000/1044310 combos processados, ETA ≈ 0h 5m 2s
# 637000/1044310 combos processados, ETA ≈ 0h 5m 1s
# 638000/1044310 combos processados, ETA ≈ 0h 5m 0s
# 639000/1044310 combos processados, ETA ≈ 0h 4m 59s
# 640000/1044310 combos processados, ETA ≈ 0h 4m 58s
# 641000/1044310 combos processados, ETA ≈ 0h 4m 57s
# 642000/1044310 combos processados, ETA ≈ 0h 4m 57s
# 643000/1044310 combos processados, ETA ≈ 0h 4m 56s
# 644000/1044310 combos processados, ETA ≈ 0h 4m 55s
# 645000/1044310 combos processados, ETA ≈ 0h 4m 54s
# 646000/1044310 combos processados, ETA ≈ 0h 4m 53s
# 647000/1044310 combos processados, ETA ≈ 0h 4m 52s
# 648000/1044310 combos processados, ETA ≈ 0h 4m 52s
# 649000/1044310 combos processados, ETA ≈ 0h 4m 51s
# 650000/1044310 combos processados, ETA ≈ 0h 4m 50s
# 651000/1044310 combos processados, ETA ≈ 0h 4m 49s
# 652000/1044310 combos processados, ETA ≈ 0h 4m 48s
# 653000/1044310 combos processados, ETA ≈ 0h 4m 47s
# 654000/1044310 combos processados, ETA ≈ 0h 4m 46s
# 655000/1044310 combos processados, ETA ≈ 0h 4m 45s
# 656000/1044310 combos processados, ETA ≈ 0h 4m 44s
# 657000/1044310 combos processados, ETA ≈ 0h 4m 44s
# 658000/1044310 combos processados, ETA ≈ 0h 4m 43s
# 659000/1044310 combos processados, ETA ≈ 0h 4m 42s
# 660000/1044310 combos processados, ETA ≈ 0h 4m 41s
# 661000/1044310 combos processados, ETA ≈ 0h 4m 40s
# 662000/1044310 combos processados, ETA ≈ 0h 4m 39s
# 663000/1044310 combos processados, ETA ≈ 0h 4m 39s
# 664000/1044310 combos processados, ETA ≈ 0h 4m 38s
# 665000/1044310 combos processados, ETA ≈ 0h 4m 37s
# 666000/1044310 combos processados, ETA ≈ 0h 4m 36s
# 667000/1044310 combos processados, ETA ≈ 0h 4m 35s
# 668000/1044310 combos processados, ETA ≈ 0h 4m 34s
# 669000/1044310 combos processados, ETA ≈ 0h 4m 33s
# 670000/1044310 combos processados, ETA ≈ 0h 4m 32s
# 671000/1044310 combos processados, ETA ≈ 0h 4m 31s
# 672000/1044310 combos processados, ETA ≈ 0h 4m 30s
# 673000/1044310 combos processados, ETA ≈ 0h 4m 29s
# 674000/1044310 combos processados, ETA ≈ 0h 4m 29s
# 675000/1044310 combos processados, ETA ≈ 0h 4m 28s
# 676000/1044310 combos processados, ETA ≈ 0h 4m 27s
# 677000/1044310 combos processados, ETA ≈ 0h 4m 26s
# 678000/1044310 combos processados, ETA ≈ 0h 4m 25s
# 679000/1044310 combos processados, ETA ≈ 0h 4m 24s
# 680000/1044310 combos processados, ETA ≈ 0h 4m 23s
# 681000/1044310 combos processados, ETA ≈ 0h 4m 22s
# 682000/1044310 combos processados, ETA ≈ 0h 4m 22s
# 683000/1044310 combos processados, ETA ≈ 0h 4m 21s
# 684000/1044310 combos processados, ETA ≈ 0h 4m 20s
# 685000/1044310 combos processados, ETA ≈ 0h 4m 20s
# 686000/1044310 combos processados, ETA ≈ 0h 4m 19s
# 687000/1044310 combos processados, ETA ≈ 0h 4m 18s
# 688000/1044310 combos processados, ETA ≈ 0h 4m 18s
# 689000/1044310 combos processados, ETA ≈ 0h 4m 17s
# 690000/1044310 combos processados, ETA ≈ 0h 4m 17s
# 691000/1044310 combos processados, ETA ≈ 0h 4m 17s
# 692000/1044310 combos processados, ETA ≈ 0h 4m 17s
# 693000/1044310 combos processados, ETA ≈ 0h 4m 16s
# 694000/1044310 combos processados, ETA ≈ 0h 4m 15s
# 695000/1044310 combos processados, ETA ≈ 0h 4m 14s
# 696000/1044310 combos processados, ETA ≈ 0h 4m 14s
# 697000/1044310 combos processados, ETA ≈ 0h 4m 13s
# 698000/1044310 combos processados, ETA ≈ 0h 4m 12s
# 699000/1044310 combos processados, ETA ≈ 0h 4m 11s
# 700000/1044310 combos processados, ETA ≈ 0h 4m 11s
# 701000/1044310 combos processados, ETA ≈ 0h 4m 10s
# 702000/1044310 combos processados, ETA ≈ 0h 4m 10s
# 703000/1044310 combos processados, ETA ≈ 0h 4m 9s
# 704000/1044310 combos processados, ETA ≈ 0h 4m 8s
# 705000/1044310 combos processados, ETA ≈ 0h 4m 7s
# 706000/1044310 combos processados, ETA ≈ 0h 4m 6s
# 707000/1044310 combos processados, ETA ≈ 0h 4m 5s
# 708000/1044310 combos processados, ETA ≈ 0h 4m 4s
# 709000/1044310 combos processados, ETA ≈ 0h 4m 3s
# 710000/1044310 combos processados, ETA ≈ 0h 4m 3s
# 711000/1044310 combos processados, ETA ≈ 0h 4m 2s
# 712000/1044310 combos processados, ETA ≈ 0h 4m 1s
# 713000/1044310 combos processados, ETA ≈ 0h 4m 0s
# 714000/1044310 combos processados, ETA ≈ 0h 3m 59s
# 715000/1044310 combos processados, ETA ≈ 0h 3m 58s
# 716000/1044310 combos processados, ETA ≈ 0h 3m 57s
# 717000/1044310 combos processados, ETA ≈ 0h 3m 57s
# 718000/1044310 combos processados, ETA ≈ 0h 3m 57s
# 719000/1044310 combos processados, ETA ≈ 0h 3m 56s
# 720000/1044310 combos processados, ETA ≈ 0h 3m 56s
# 721000/1044310 combos processados, ETA ≈ 0h 3m 55s
# 722000/1044310 combos processados, ETA ≈ 0h 3m 54s
# 723000/1044310 combos processados, ETA ≈ 0h 3m 53s
# 724000/1044310 combos processados, ETA ≈ 0h 3m 52s
# 725000/1044310 combos processados, ETA ≈ 0h 3m 52s
# 726000/1044310 combos processados, ETA ≈ 0h 3m 51s
# 727000/1044310 combos processados, ETA ≈ 0h 3m 50s
# 728000/1044310 combos processados, ETA ≈ 0h 3m 49s
# 729000/1044310 combos processados, ETA ≈ 0h 3m 48s
# 730000/1044310 combos processados, ETA ≈ 0h 3m 48s
# 731000/1044310 combos processados, ETA ≈ 0h 3m 47s
# 732000/1044310 combos processados, ETA ≈ 0h 3m 46s
# 733000/1044310 combos processados, ETA ≈ 0h 3m 46s
# 734000/1044310 combos processados, ETA ≈ 0h 3m 45s
# 735000/1044310 combos processados, ETA ≈ 0h 3m 45s
# 736000/1044310 combos processados, ETA ≈ 0h 3m 44s
# 737000/1044310 combos processados, ETA ≈ 0h 3m 43s
# 738000/1044310 combos processados, ETA ≈ 0h 3m 42s
# 739000/1044310 combos processados, ETA ≈ 0h 3m 41s
# 740000/1044310 combos processados, ETA ≈ 0h 3m 40s
# 741000/1044310 combos processados, ETA ≈ 0h 3m 40s
# 742000/1044310 combos processados, ETA ≈ 0h 3m 39s
# 743000/1044310 combos processados, ETA ≈ 0h 3m 38s
# 744000/1044310 combos processados, ETA ≈ 0h 3m 37s
# 745000/1044310 combos processados, ETA ≈ 0h 3m 36s
# 746000/1044310 combos processados, ETA ≈ 0h 3m 35s
# 747000/1044310 combos processados, ETA ≈ 0h 3m 34s
# 748000/1044310 combos processados, ETA ≈ 0h 3m 34s
# 749000/1044310 combos processados, ETA ≈ 0h 3m 33s
# 750000/1044310 combos processados, ETA ≈ 0h 3m 32s
# 751000/1044310 combos processados, ETA ≈ 0h 3m 31s
# 752000/1044310 combos processados, ETA ≈ 0h 3m 30s
# 753000/1044310 combos processados, ETA ≈ 0h 3m 29s
# 754000/1044310 combos processados, ETA ≈ 0h 3m 28s
# 755000/1044310 combos processados, ETA ≈ 0h 3m 28s
# 756000/1044310 combos processados, ETA ≈ 0h 3m 27s
# 757000/1044310 combos processados, ETA ≈ 0h 3m 26s
# 758000/1044310 combos processados, ETA ≈ 0h 3m 25s
# 759000/1044310 combos processados, ETA ≈ 0h 3m 24s
# 760000/1044310 combos processados, ETA ≈ 0h 3m 23s
# 761000/1044310 combos processados, ETA ≈ 0h 3m 22s
# 762000/1044310 combos processados, ETA ≈ 0h 3m 22s
# 763000/1044310 combos processados, ETA ≈ 0h 3m 21s
# 764000/1044310 combos processados, ETA ≈ 0h 3m 20s
# 765000/1044310 combos processados, ETA ≈ 0h 3m 19s
# 766000/1044310 combos processados, ETA ≈ 0h 3m 19s
# 767000/1044310 combos processados, ETA ≈ 0h 3m 18s
# 768000/1044310 combos processados, ETA ≈ 0h 3m 17s
# 769000/1044310 combos processados, ETA ≈ 0h 3m 16s
# 770000/1044310 combos processados, ETA ≈ 0h 3m 15s
# 771000/1044310 combos processados, ETA ≈ 0h 3m 15s
# 772000/1044310 combos processados, ETA ≈ 0h 3m 14s
# 773000/1044310 combos processados, ETA ≈ 0h 3m 13s
# 774000/1044310 combos processados, ETA ≈ 0h 3m 13s
# 775000/1044310 combos processados, ETA ≈ 0h 3m 13s
# 776000/1044310 combos processados, ETA ≈ 0h 3m 12s
# 777000/1044310 combos processados, ETA ≈ 0h 3m 12s
# 778000/1044310 combos processados, ETA ≈ 0h 3m 11s
# 779000/1044310 combos processados, ETA ≈ 0h 3m 10s
# 780000/1044310 combos processados, ETA ≈ 0h 3m 9s
# 781000/1044310 combos processados, ETA ≈ 0h 3m 9s
# 782000/1044310 combos processados, ETA ≈ 0h 3m 8s
# 783000/1044310 combos processados, ETA ≈ 0h 3m 7s
# 784000/1044310 combos processados, ETA ≈ 0h 3m 6s
# 785000/1044310 combos processados, ETA ≈ 0h 3m 6s
# 786000/1044310 combos processados, ETA ≈ 0h 3m 5s
# 787000/1044310 combos processados, ETA ≈ 0h 3m 4s
# 788000/1044310 combos processados, ETA ≈ 0h 3m 4s
# 789000/1044310 combos processados, ETA ≈ 0h 3m 3s
# 790000/1044310 combos processados, ETA ≈ 0h 3m 3s
# 791000/1044310 combos processados, ETA ≈ 0h 3m 2s
# 792000/1044310 combos processados, ETA ≈ 0h 3m 1s
# 793000/1044310 combos processados, ETA ≈ 0h 3m 0s
# 794000/1044310 combos processados, ETA ≈ 0h 3m 0s
# 795000/1044310 combos processados, ETA ≈ 0h 2m 59s
# 796000/1044310 combos processados, ETA ≈ 0h 2m 58s
# 797000/1044310 combos processados, ETA ≈ 0h 2m 57s
# 798000/1044310 combos processados, ETA ≈ 0h 2m 57s
# 799000/1044310 combos processados, ETA ≈ 0h 2m 56s
# 800000/1044310 combos processados, ETA ≈ 0h 2m 55s
# 801000/1044310 combos processados, ETA ≈ 0h 2m 54s
# 802000/1044310 combos processados, ETA ≈ 0h 2m 53s
# 803000/1044310 combos processados, ETA ≈ 0h 2m 52s
# 804000/1044310 combos processados, ETA ≈ 0h 2m 52s
# 805000/1044310 combos processados, ETA ≈ 0h 2m 51s
# 806000/1044310 combos processados, ETA ≈ 0h 2m 50s
# 807000/1044310 combos processados, ETA ≈ 0h 2m 50s
# 808000/1044310 combos processados, ETA ≈ 0h 2m 49s
# 809000/1044310 combos processados, ETA ≈ 0h 2m 48s
# 810000/1044310 combos processados, ETA ≈ 0h 2m 47s
# 811000/1044310 combos processados, ETA ≈ 0h 2m 47s
# 812000/1044310 combos processados, ETA ≈ 0h 2m 46s
# 813000/1044310 combos processados, ETA ≈ 0h 2m 45s
# 814000/1044310 combos processados, ETA ≈ 0h 2m 45s
# 815000/1044310 combos processados, ETA ≈ 0h 2m 44s
# 816000/1044310 combos processados, ETA ≈ 0h 2m 43s
# 817000/1044310 combos processados, ETA ≈ 0h 2m 42s
# 818000/1044310 combos processados, ETA ≈ 0h 2m 41s
# 819000/1044310 combos processados, ETA ≈ 0h 2m 40s
# 820000/1044310 combos processados, ETA ≈ 0h 2m 40s
# 821000/1044310 combos processados, ETA ≈ 0h 2m 39s
# 822000/1044310 combos processados, ETA ≈ 0h 2m 38s
# 823000/1044310 combos processados, ETA ≈ 0h 2m 37s
# 824000/1044310 combos processados, ETA ≈ 0h 2m 36s
# 825000/1044310 combos processados, ETA ≈ 0h 2m 36s
# 826000/1044310 combos processados, ETA ≈ 0h 2m 35s
# 827000/1044310 combos processados, ETA ≈ 0h 2m 34s
# 828000/1044310 combos processados, ETA ≈ 0h 2m 33s
# 829000/1044310 combos processados, ETA ≈ 0h 2m 33s
# 830000/1044310 combos processados, ETA ≈ 0h 2m 32s
# 831000/1044310 combos processados, ETA ≈ 0h 2m 31s
# 832000/1044310 combos processados, ETA ≈ 0h 2m 30s
# 833000/1044310 combos processados, ETA ≈ 0h 2m 30s
# 834000/1044310 combos processados, ETA ≈ 0h 2m 29s
# 835000/1044310 combos processados, ETA ≈ 0h 2m 28s
# 836000/1044310 combos processados, ETA ≈ 0h 2m 27s
# 837000/1044310 combos processados, ETA ≈ 0h 2m 27s
# 838000/1044310 combos processados, ETA ≈ 0h 2m 26s
# 839000/1044310 combos processados, ETA ≈ 0h 2m 25s
# 840000/1044310 combos processados, ETA ≈ 0h 2m 24s
# 841000/1044310 combos processados, ETA ≈ 0h 2m 24s
# 842000/1044310 combos processados, ETA ≈ 0h 2m 23s
# 843000/1044310 combos processados, ETA ≈ 0h 2m 22s
# 844000/1044310 combos processados, ETA ≈ 0h 2m 21s
# 845000/1044310 combos processados, ETA ≈ 0h 2m 21s
# 846000/1044310 combos processados, ETA ≈ 0h 2m 20s
# 847000/1044310 combos processados, ETA ≈ 0h 2m 19s
# 848000/1044310 combos processados, ETA ≈ 0h 2m 18s
# 849000/1044310 combos processados, ETA ≈ 0h 2m 17s
# 850000/1044310 combos processados, ETA ≈ 0h 2m 17s
# 851000/1044310 combos processados, ETA ≈ 0h 2m 16s
# 852000/1044310 combos processados, ETA ≈ 0h 2m 15s
# 853000/1044310 combos processados, ETA ≈ 0h 2m 14s
# 854000/1044310 combos processados, ETA ≈ 0h 2m 14s
# 855000/1044310 combos processados, ETA ≈ 0h 2m 13s
# 856000/1044310 combos processados, ETA ≈ 0h 2m 12s
# 857000/1044310 combos processados, ETA ≈ 0h 2m 12s
# 858000/1044310 combos processados, ETA ≈ 0h 2m 11s
# 859000/1044310 combos processados, ETA ≈ 0h 2m 10s
# 860000/1044310 combos processados, ETA ≈ 0h 2m 10s
# 861000/1044310 combos processados, ETA ≈ 0h 2m 9s
# 862000/1044310 combos processados, ETA ≈ 0h 2m 8s
# 863000/1044310 combos processados, ETA ≈ 0h 2m 8s
# 864000/1044310 combos processados, ETA ≈ 0h 2m 7s
# 865000/1044310 combos processados, ETA ≈ 0h 2m 7s
# 866000/1044310 combos processados, ETA ≈ 0h 2m 6s
# 867000/1044310 combos processados, ETA ≈ 0h 2m 6s
# 868000/1044310 combos processados, ETA ≈ 0h 2m 5s
# 869000/1044310 combos processados, ETA ≈ 0h 2m 4s
# 870000/1044310 combos processados, ETA ≈ 0h 2m 3s
# 871000/1044310 combos processados, ETA ≈ 0h 2m 3s
# 872000/1044310 combos processados, ETA ≈ 0h 2m 2s
# 873000/1044310 combos processados, ETA ≈ 0h 2m 1s
# 874000/1044310 combos processados, ETA ≈ 0h 2m 0s
# 875000/1044310 combos processados, ETA ≈ 0h 2m 0s
# 876000/1044310 combos processados, ETA ≈ 0h 1m 59s
# 877000/1044310 combos processados, ETA ≈ 0h 1m 58s
# 878000/1044310 combos processados, ETA ≈ 0h 1m 57s
# 879000/1044310 combos processados, ETA ≈ 0h 1m 56s
# 880000/1044310 combos processados, ETA ≈ 0h 1m 56s
# 881000/1044310 combos processados, ETA ≈ 0h 1m 55s
# 882000/1044310 combos processados, ETA ≈ 0h 1m 54s
# 883000/1044310 combos processados, ETA ≈ 0h 1m 54s
# 884000/1044310 combos processados, ETA ≈ 0h 1m 53s
# 885000/1044310 combos processados, ETA ≈ 0h 1m 52s
# 886000/1044310 combos processados, ETA ≈ 0h 1m 52s
# 887000/1044310 combos processados, ETA ≈ 0h 1m 51s
# 888000/1044310 combos processados, ETA ≈ 0h 1m 50s
# 889000/1044310 combos processados, ETA ≈ 0h 1m 50s
# 890000/1044310 combos processados, ETA ≈ 0h 1m 49s
# 891000/1044310 combos processados, ETA ≈ 0h 1m 48s
# 892000/1044310 combos processados, ETA ≈ 0h 1m 47s
# 893000/1044310 combos processados, ETA ≈ 0h 1m 46s
# 894000/1044310 combos processados, ETA ≈ 0h 1m 46s
# 895000/1044310 combos processados, ETA ≈ 0h 1m 45s
# 896000/1044310 combos processados, ETA ≈ 0h 1m 44s
# 897000/1044310 combos processados, ETA ≈ 0h 1m 44s
# 898000/1044310 combos processados, ETA ≈ 0h 1m 43s
# 899000/1044310 combos processados, ETA ≈ 0h 1m 42s
# 900000/1044310 combos processados, ETA ≈ 0h 1m 41s
# 901000/1044310 combos processados, ETA ≈ 0h 1m 41s
# 902000/1044310 combos processados, ETA ≈ 0h 1m 40s
# 903000/1044310 combos processados, ETA ≈ 0h 1m 40s
# 904000/1044310 combos processados, ETA ≈ 0h 1m 39s
# 905000/1044310 combos processados, ETA ≈ 0h 1m 38s
# 906000/1044310 combos processados, ETA ≈ 0h 1m 38s
# 907000/1044310 combos processados, ETA ≈ 0h 1m 37s
# 908000/1044310 combos processados, ETA ≈ 0h 1m 36s
# 909000/1044310 combos processados, ETA ≈ 0h 1m 36s
# 910000/1044310 combos processados, ETA ≈ 0h 1m 35s
# 911000/1044310 combos processados, ETA ≈ 0h 1m 34s
# 912000/1044310 combos processados, ETA ≈ 0h 1m 33s
# 913000/1044310 combos processados, ETA ≈ 0h 1m 33s
# 914000/1044310 combos processados, ETA ≈ 0h 1m 32s
# 915000/1044310 combos processados, ETA ≈ 0h 1m 31s
# 916000/1044310 combos processados, ETA ≈ 0h 1m 30s
# 917000/1044310 combos processados, ETA ≈ 0h 1m 30s
# 918000/1044310 combos processados, ETA ≈ 0h 1m 29s
# 919000/1044310 combos processados, ETA ≈ 0h 1m 28s
# 920000/1044310 combos processados, ETA ≈ 0h 1m 28s
# 921000/1044310 combos processados, ETA ≈ 0h 1m 27s
# 922000/1044310 combos processados, ETA ≈ 0h 1m 26s
# 923000/1044310 combos processados, ETA ≈ 0h 1m 25s
# 924000/1044310 combos processados, ETA ≈ 0h 1m 25s
# 925000/1044310 combos processados, ETA ≈ 0h 1m 24s
# 926000/1044310 combos processados, ETA ≈ 0h 1m 23s
# 927000/1044310 combos processados, ETA ≈ 0h 1m 22s
# 928000/1044310 combos processados, ETA ≈ 0h 1m 22s
# 929000/1044310 combos processados, ETA ≈ 0h 1m 21s
# 930000/1044310 combos processados, ETA ≈ 0h 1m 20s
# 931000/1044310 combos processados, ETA ≈ 0h 1m 20s
# 932000/1044310 combos processados, ETA ≈ 0h 1m 19s
# 933000/1044310 combos processados, ETA ≈ 0h 1m 18s
# 934000/1044310 combos processados, ETA ≈ 0h 1m 17s
# 935000/1044310 combos processados, ETA ≈ 0h 1m 17s
# 936000/1044310 combos processados, ETA ≈ 0h 1m 16s
# 937000/1044310 combos processados, ETA ≈ 0h 1m 15s
# 938000/1044310 combos processados, ETA ≈ 0h 1m 15s
# 939000/1044310 combos processados, ETA ≈ 0h 1m 14s
# 940000/1044310 combos processados, ETA ≈ 0h 1m 14s
# 941000/1044310 combos processados, ETA ≈ 0h 1m 13s
# 942000/1044310 combos processados, ETA ≈ 0h 1m 12s
# 943000/1044310 combos processados, ETA ≈ 0h 1m 11s
# 944000/1044310 combos processados, ETA ≈ 0h 1m 11s
# 945000/1044310 combos processados, ETA ≈ 0h 1m 10s
# 946000/1044310 combos processados, ETA ≈ 0h 1m 9s
# 947000/1044310 combos processados, ETA ≈ 0h 1m 9s
# 948000/1044310 combos processados, ETA ≈ 0h 1m 8s
# 949000/1044310 combos processados, ETA ≈ 0h 1m 7s
# 950000/1044310 combos processados, ETA ≈ 0h 1m 6s
# 951000/1044310 combos processados, ETA ≈ 0h 1m 6s
# 952000/1044310 combos processados, ETA ≈ 0h 1m 5s
# 953000/1044310 combos processados, ETA ≈ 0h 1m 4s
# 954000/1044310 combos processados, ETA ≈ 0h 1m 3s
# 955000/1044310 combos processados, ETA ≈ 0h 1m 3s
# 956000/1044310 combos processados, ETA ≈ 0h 1m 2s
# 957000/1044310 combos processados, ETA ≈ 0h 1m 1s
# 958000/1044310 combos processados, ETA ≈ 0h 1m 1s
# 959000/1044310 combos processados, ETA ≈ 0h 1m 0s
# 960000/1044310 combos processados, ETA ≈ 0h 0m 59s
# 961000/1044310 combos processados, ETA ≈ 0h 0m 58s
# 962000/1044310 combos processados, ETA ≈ 0h 0m 58s
# 963000/1044310 combos processados, ETA ≈ 0h 0m 57s
# 964000/1044310 combos processados, ETA ≈ 0h 0m 57s
# 965000/1044310 combos processados, ETA ≈ 0h 0m 56s
# 966000/1044310 combos processados, ETA ≈ 0h 0m 55s
# 967000/1044310 combos processados, ETA ≈ 0h 0m 54s
# 968000/1044310 combos processados, ETA ≈ 0h 0m 54s
# 969000/1044310 combos processados, ETA ≈ 0h 0m 53s
# 970000/1044310 combos processados, ETA ≈ 0h 0m 52s
# 971000/1044310 combos processados, ETA ≈ 0h 0m 52s
# 972000/1044310 combos processados, ETA ≈ 0h 0m 51s
# 973000/1044310 combos processados, ETA ≈ 0h 0m 50s
# 974000/1044310 combos processados, ETA ≈ 0h 0m 49s
# 975000/1044310 combos processados, ETA ≈ 0h 0m 49s
# 976000/1044310 combos processados, ETA ≈ 0h 0m 48s
# 977000/1044310 combos processados, ETA ≈ 0h 0m 47s
# 978000/1044310 combos processados, ETA ≈ 0h 0m 47s
# 979000/1044310 combos processados, ETA ≈ 0h 0m 46s
# 980000/1044310 combos processados, ETA ≈ 0h 0m 45s
# 981000/1044310 combos processados, ETA ≈ 0h 0m 44s
# 982000/1044310 combos processados, ETA ≈ 0h 0m 44s
# 983000/1044310 combos processados, ETA ≈ 0h 0m 43s
# 984000/1044310 combos processados, ETA ≈ 0h 0m 42s
# 985000/1044310 combos processados, ETA ≈ 0h 0m 42s
# 986000/1044310 combos processados, ETA ≈ 0h 0m 41s
# 987000/1044310 combos processados, ETA ≈ 0h 0m 40s
# 988000/1044310 combos processados, ETA ≈ 0h 0m 39s
# 989000/1044310 combos processados, ETA ≈ 0h 0m 39s
# 990000/1044310 combos processados, ETA ≈ 0h 0m 38s
# 991000/1044310 combos processados, ETA ≈ 0h 0m 37s
# 992000/1044310 combos processados, ETA ≈ 0h 0m 37s
# 993000/1044310 combos processados, ETA ≈ 0h 0m 36s
# 994000/1044310 combos processados, ETA ≈ 0h 0m 35s
# 995000/1044310 combos processados, ETA ≈ 0h 0m 34s
# 996000/1044310 combos processados, ETA ≈ 0h 0m 34s
# 997000/1044310 combos processados, ETA ≈ 0h 0m 33s
# 998000/1044310 combos processados, ETA ≈ 0h 0m 32s
# 999000/1044310 combos processados, ETA ≈ 0h 0m 32s
# 1000000/1044310 combos processados, ETA ≈ 0h 0m 31s
# 1001000/1044310 combos processados, ETA ≈ 0h 0m 30s
# 1002000/1044310 combos processados, ETA ≈ 0h 0m 29s
# 1003000/1044310 combos processados, ETA ≈ 0h 0m 29s
# 1004000/1044310 combos processados, ETA ≈ 0h 0m 28s
# 1005000/1044310 combos processados, ETA ≈ 0h 0m 27s
# 1006000/1044310 combos processados, ETA ≈ 0h 0m 27s
# 1007000/1044310 combos processados, ETA ≈ 0h 0m 26s
# 1008000/1044310 combos processados, ETA ≈ 0h 0m 25s
# 1009000/1044310 combos processados, ETA ≈ 0h 0m 25s
# 1010000/1044310 combos processados, ETA ≈ 0h 0m 24s
# 1011000/1044310 combos processados, ETA ≈ 0h 0m 23s
# 1012000/1044310 combos processados, ETA ≈ 0h 0m 23s
# 1013000/1044310 combos processados, ETA ≈ 0h 0m 22s
# 1014000/1044310 combos processados, ETA ≈ 0h 0m 21s
# 1015000/1044310 combos processados, ETA ≈ 0h 0m 20s
# 1016000/1044310 combos processados, ETA ≈ 0h 0m 20s
# 1017000/1044310 combos processados, ETA ≈ 0h 0m 19s
# 1018000/1044310 combos processados, ETA ≈ 0h 0m 18s
# 1019000/1044310 combos processados, ETA ≈ 0h 0m 18s
# 1020000/1044310 combos processados, ETA ≈ 0h 0m 17s
# 1021000/1044310 combos processados, ETA ≈ 0h 0m 16s
# 1022000/1044310 combos processados, ETA ≈ 0h 0m 15s
# 1023000/1044310 combos processados, ETA ≈ 0h 0m 15s
# 1024000/1044310 combos processados, ETA ≈ 0h 0m 14s
# 1025000/1044310 combos processados, ETA ≈ 0h 0m 13s
# 1026000/1044310 combos processados, ETA ≈ 0h 0m 13s
# 1027000/1044310 combos processados, ETA ≈ 0h 0m 12s
# 1028000/1044310 combos processados, ETA ≈ 0h 0m 11s
# 1029000/1044310 combos processados, ETA ≈ 0h 0m 10s
# 1030000/1044310 combos processados, ETA ≈ 0h 0m 10s
# 1031000/1044310 combos processados, ETA ≈ 0h 0m 9s
# 1032000/1044310 combos processados, ETA ≈ 0h 0m 8s
# 1033000/1044310 combos processados, ETA ≈ 0h 0m 8s
# 1034000/1044310 combos processados, ETA ≈ 0h 0m 7s
# 1035000/1044310 combos processados, ETA ≈ 0h 0m 6s
# 1036000/1044310 combos processados, ETA ≈ 0h 0m 5s
# 1037000/1044310 combos processados, ETA ≈ 0h 0m 5s
# 1038000/1044310 combos processados, ETA ≈ 0h 0m 4s
# 1039000/1044310 combos processados, ETA ≈ 0h 0m 3s
# 1040000/1044310 combos processados, ETA ≈ 0h 0m 3s
# 1041000/1044310 combos processados, ETA ≈ 0h 0m 2s
# 1042000/1044310 combos processados, ETA ≈ 0h 0m 1s
# 1043000/1044310 combos processados, ETA ≈ 0h 0m 0s
# 1044000/1044310 combos processados, ETA ≈ 0h 0m 0s
# 1044310/1044310 combos processados, ETA ≈ 0h 0m 0s
# ✅ Arquivo 'previsoes_2023_mlp.parquet' gerado com sucesso!
#     semana                  pdv              produto  quantidade
# 0        1  3820079530528229795  1000423277513436210           1
# 1        2  3820079530528229795  1000423277513436210           1
# 2        3  3820079530528229795  1000423277513436210           1
# 3        4  3820079530528229795  1000423277513436210           1
# 4        5  3820079530528229795  1000423277513436210           1
# 5        1  7360454609632053666  1000423277513436210           1
# 6        2  7360454609632053666  1000423277513436210           1
# 7        3  7360454609632053666  1000423277513436210           1
# 8        4  7360454609632053666  1000423277513436210           1
# 9        5  7360454609632053666  1000423277513436210           1
# 10       1  1506449269697977323  1004943868572044494           3
# 11       2  1506449269697977323  1004943868572044494           4
# 12       3  1506449269697977323  1004943868572044494           4
# 13       4  1506449269697977323  1004943868572044494           4
# 14       5  1506449269697977323  1004943868572044494           4
# 15       1  1001371918471115422  1009179103632945474           2
# 16       2  1001371918471115422  1009179103632945474           2
# 17       3  1001371918471115422  1009179103632945474           2
# 18       4  1001371918471115422  1009179103632945474           2
# 19       5  1001371918471115422  1009179103632945474           2

# %%
# ================================
# !pip install pandas pyarrow torch tqdm joblib
# ================================

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import warnings
import joblib
import time

warnings.filterwarnings("ignore")

# ================================
# Configuração GPU
# ================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("🚀 Usando dispositivo:", device)

# ================================
# Função para carregar dados
# ================================
def carregar_dados():
    df = pd.read_parquet("dados_tratados_sem_nan.parquet")
    df = df.rename(columns={
        "internal_store_id": "pdv",
        "internal_product_id": "produto",
        "quantity": "quantidade"
    })
    df = df.sort_values(["produto", "pdv", "semana"])
    df["produto"] = df["produto"].astype(str).str.strip()
    df["pdv"] = df["pdv"].astype(str).str.strip()
    return df[["semana", "pdv", "produto", "quantidade", "quantity_smooth"]]

# ================================
# Rede Neural Global (MLP simples)
# ================================
class MLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        return self.fc3(x)

# ================================
# Preparar dataset global
# ================================
def preparar_dataset_global(df, window=10):
    X, y, grupos = [], [], []
    for (produto, pdv), grupo in df.groupby(["produto", "pdv"]):
        serie = grupo["quantity_smooth"].fillna(method="ffill").dropna().values
        if len(serie) < 10:  # apenas séries com ≥10 semanas
            continue
        for i in range(len(serie) - window):
            X.append(serie[i:i+window])
            y.append(serie[i+window])
            grupos.append((produto, pdv))
    return np.array(X), np.array(y), grupos

# ================================
# Execução principal
# ================================
if __name__ == "__main__":
    # Parâmetros
    window = 10
    batch_size = 1024
    num_epochs = 30

    # Carregar dados
    df = carregar_dados()
    print("📊 Preparando dataset global...")
    X, y, grupos = preparar_dataset_global(df, window=window)

    print(f"🔹 Séries válidas: {len(grupos)}, amostras: {len(X)}")

    # Tensores
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32).view(-1, 1)

    dataset = TensorDataset(X_tensor, y_tensor)
    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        pin_memory=True,
        num_workers=0  # remove multiprocessamento
    )

    # Modelo, loss e otimizador
    model = MLP(window).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Treino
    start_time = time.time()
    print("⚡ Treinando modelo global...")

    for epoch in range(1, num_epochs+1):
        epoch_start = time.time()
        running_loss = 0.0
        for xb, yb in loader:
            xb = xb.to(device)
            yb = yb.to(device)
            optimizer.zero_grad()
            loss = criterion(model(xb), yb)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        avg_loss = running_loss / len(loader)
        epoch_time = time.time() - epoch_start
        print(f"✅ Epoch {epoch}/{num_epochs} finalizado em {int(epoch_time//60)}m {int(epoch_time%60)}s, "
              f"Loss médio: {avg_loss:.4f}")

    total_time = time.time() - start_time
    print(f"\n⏱️ Treinamento completo em {int(total_time//3600)}h {int((total_time%3600)//60)}m {int(total_time%60)}s")

    # Salvar modelo
    torch.save(model.state_dict(), "mlp_global_2022.pth")
    joblib.dump({"window": window, "grupos": grupos}, "mlp_global_metadata.pkl")
    print("✅ Modelo global treinado e salvo!")
